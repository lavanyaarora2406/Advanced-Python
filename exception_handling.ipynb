# %% [markdown]
# There are 2 stages where error may happen in a program
#
# - During compilation -> Syntax Error
# - During execution -> Exceptions

# %% [markdown]
# ### Syntax Error
#
# - Something in the program is not written according to the program grammar.
# - Error is raised by the interpreter/compiler
# - You can solve it by rectifying the program

# %%
# Examples of syntax error
print 'hello world'

# %% [markdown]
# ### Other examples of syntax error
#
# - Leaving symbols like colon,brackets
# - Misspelling a keyword
# - Incorrect indentation
# - empty if/else/loops/class/functions

# %%
a = 5
if a==3  # no colon at the end of the if statement
    print('a is 3')
  print('hello')

# %%
a = 5
iff a==3:
  print('hello')

# %%
a = 5
if a==3:
print('hello')

# %%
# IndexError
# The IndexError is thrown when trying to access an item at an invalid index.
L = [1,2,3]
L[100]

# %%
# ModuleNotFoundError
# The ModuleNotFoundError is thrown when a module could not be found.
import mathi
math.floor(5.3)

# %%
# KeyError
# The KeyError is thrown when a key is not found

d = {'name':'nitish'}
d['age']

# %%
# TypeError
# The TypeError is thrown when an operation or function is applied to an object of an inappropriate type.
1 + 'a'

# %%
# ValueError
# The ValueError is thrown when a function's argument is of an inappropriate type.
int('a')

# %%
# NameError
# The NameError is thrown when an object could not be found.
print(k)

# %%
# AttributeError
L = [1,2,3]
L.upper()

# Stacktrace

# %% [markdown]
# ### Exceptions
#
# If things go wrong during the execution of the program(runtime). It generally happens when something unforeseen has happened.
#
# - Exceptions are raised by python runtime
# - You have to takle is on the fly
#
# #### **Examples**
#
# - Memory overflow
# - Divide by 0 -> logical error
# - Database error

# %%
# Why is it important to handle exceptions
# how to handle exceptions
# -> Try except block

# %%
# let's create a file
with open('sample.txt','w') as f:
  f.write('hello world')

# %%
# try except  demo = external things in program try to write in try except block

try :
  with open ("sample1.txt" , "r") as f:
    print(f.read())
except :
  print("File not found")

# %%
try :
    f = open('sample.txt','r')
    print(f.read())
    print (m)
    print(5/2)
    L = [1,2,3,4,5]
    L[100]
    
    
except FileNotFoundError:
    print("File not found")
except NameError :  # these are specific exceptions which we can handle in except block
    
    print("Variable not defined")
except ZeroDivisionError:
    print("some error occurred") # always try to tell nature of error in except block
except Exception as e:
    print(e)
    
except Exception as e : # general exception block which will catch all the exceptions
    
    print(e)

# %%
# else
try:
  f = open('sample.txt','r')
except FileNotFoundError:
  print('file not found')
except Exception:
  print('some error occurred')
  
else: # else block will be executed if there is no exception in try block
  print(f.read())

# %%
# finally
# else
try:
  f = open('sample.txt','r')
except FileNotFoundError:
  print('file not found')
except Exception:
  print(' there is some error ')
else:
  print(f.read())
finally: # it will be executed no matter what happens in try except block
  print('it will be printed no matter what happens in try except block ')

# %%
# raise Exception
# In Python programming, exceptions are raised when errors occur at runtime.
# We can also manually raise exceptions using the raise keyword.

# We can optionally pass values to the exception to clarify why that exception was raised

# %%
raise ZeroDivisionError('just trying ') # throwing rndom error using raise keyword

# Java
# try -> try
# except -> catch
# raise -> throw

# %%
class Bank:

  def __init__(self,balance):
    self.balance = balance

  def withdraw(self,amount):
    if amount < 0:
      raise Exception('amount cannot be -ve') # here eception acts as class which is used to create exception object
    
    if self.balance < amount:
      raise Exception(' donot have money in account')
    
    self.balance = self.balance - amount

obj = Bank(10000)
try:
  obj.withdraw(15)
except Exception as e:
  print(e)
else:
  print(obj.balance)

# %%
class MyException(Exception): # you have to inherit from Exception class to create your own exception class and then you can create your own exception object and myexception class acts as parent class for your own exception class
  
  def __init__(self,message):
    print(message)

class Bank:

  def __init__(self,balance):
    self.balance = balance

  def withdraw(self,amount):
    if amount < 0:
      raise MyException('amount cannot be -ve')
    if self.balance < amount:
      raise MyException('paise nai hai tere paas')
    self.balance = self.balance - amount

obj = Bank(10000)
try:
  obj.withdraw(5000)
except MyException as e:
  pass
else:
  print(obj.balance)

# %%
# creating custom exceptions = your own exceptions  
# exception hierarchy in python

# %%
# simple example

# %%
class SecurityError(Exception): # sub class of Exception class which is used to create custom exception class
  

  def __init__(self,message):
    print(message)

  def logout(self): # custom classes are made when we want to add some extra functionality to the exception class or to our own class .....
    print('logout')

class Google:

  def __init__(self,name,email,password,device):
    self.name = name
    self.email = email
    self.password = password
    self.device = device

  def login(self,email,password,device):
    if device != self.device:
      raise SecurityError(' it has been detected that you are trying to login from different device ')
    if email == self.email and password == self.password:
      print('welcome')
    else:
      print('login error')



obj = Google('luv','lavaya@gmail.com','1234','android')

try:
  obj.login('lavaya@gmail.com','1234','windows')
except SecurityError as e:
  e.logout()
else:
  print(obj.name)
finally:
  print('database connection closed')
